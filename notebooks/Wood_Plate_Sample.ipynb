# %% [markdown]
# ## Import dependencies

# %%
import sys
import pathlib
current_path = pathlib.Path().absolute()
root_path = "{0}/..".format(current_path)
sys.path.append("{0}/src".format(root_path))

import os
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from utils import Config, ImageUtil, create_model

# %%
seed_value = 33
os.environ["PYTHONHASHSEED"] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

physical_devices = tf.config.list_physical_devices("GPU")
try:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
    # Invalid device or cannot modify virtual devices once initialized.
    pass

# %% [markdown]
# ## Prepare configuration (training and test)

# %%
image_util = ImageUtil()
config_path = "{0}/config/anomaly_detection_wood_plate.json".format(root_path)
config = Config(config_path)

# Select the predefined model
config.model = "vanilla_unet"

# Set training configuration
config.train.files_path = "{0}/img/wood_plate/train".format(root_path)
config.train.mask_files_path = "{0}/masks".format(config.train.files_path)
config.train.checkpoints_path = "{0}/checkpoints/wood_plate".format(root_path)
config.train.learning_rate = 1e-5
config.train.batch_size = 10
config.train.epochs = 50

# Set eval configuration (will be used for prediction)
config.eval.files_path = "{0}/img/wood_plate/eval".format(root_path)
config.eval.threshold = 0.1

# We only have few images, so we will creare some new augmented
config.train.image_data_generator.loop_count = 10

# %% [markdown]
# ## Create model

# %%
model_container = create_model(config)

# %% [markdown]
# ## Train model

# %%
model_container.train()
# Out:
# Train on 192 samples, validate on 48 samples
# Epoch 1/50
# 192/192 [==============================] - 9s 48ms/sample - loss: 0.1137 - accuracy: 0.9838 - val_loss: 0.0711 - val_accuracy: 0.9911
# Epoch 2/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0798 - accuracy: 0.9910 - val_loss: 0.0580 - val_accuracy: 0.9913
# Epoch 3/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0636 - accuracy: 0.9922 - val_loss: 0.0512 - val_accuracy: 0.9913
# Epoch 4/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0545 - accuracy: 0.9925 - val_loss: 0.0477 - val_accuracy: 0.9913
# Epoch 5/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0490 - accuracy: 0.9927 - val_loss: 0.0456 - val_accuracy: 0.9913
# Epoch 6/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0455 - accuracy: 0.9927 - val_loss: 0.0444 - val_accuracy: 0.9913
# Epoch 7/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0434 - accuracy: 0.9928 - val_loss: 0.0438 - val_accuracy: 0.9913
# Epoch 8/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0420 - accuracy: 0.9928 - val_loss: 0.0434 - val_accuracy: 0.9913
# Epoch 9/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0408 - accuracy: 0.9928 - val_loss: 0.0432 - val_accuracy: 0.9913
# Epoch 10/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0400 - accuracy: 0.9929 - val_loss: 0.0430 - val_accuracy: 0.9913
# Epoch 11/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0394 - accuracy: 0.9929 - val_loss: 0.0428 - val_accuracy: 0.9913
# Epoch 12/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0390 - accuracy: 0.9929 - val_loss: 0.0425 - val_accuracy: 0.9913
# Epoch 13/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0385 - accuracy: 0.9929 - val_loss: 0.0423 - val_accuracy: 0.9913
# Epoch 14/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0381 - accuracy: 0.9929 - val_loss: 0.0420 - val_accuracy: 0.9913
# Epoch 15/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0377 - accuracy: 0.9929 - val_loss: 0.0416 - val_accuracy: 0.9913
# Epoch 16/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0372 - accuracy: 0.9929 - val_loss: 0.0409 - val_accuracy: 0.9913
# Epoch 17/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0366 - accuracy: 0.9929 - val_loss: 0.0402 - val_accuracy: 0.9913
# Epoch 18/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0358 - accuracy: 0.9929 - val_loss: 0.0392 - val_accuracy: 0.9913
# Epoch 19/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0347 - accuracy: 0.9929 - val_loss: 0.0377 - val_accuracy: 0.9913
# Epoch 20/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0336 - accuracy: 0.9929 - val_loss: 0.0361 - val_accuracy: 0.9913
# Epoch 21/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0315 - accuracy: 0.9930 - val_loss: 0.0333 - val_accuracy: 0.9914
# Epoch 22/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0291 - accuracy: 0.9931 - val_loss: 0.0301 - val_accuracy: 0.9915
# Epoch 23/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0270 - accuracy: 0.9933 - val_loss: 0.0277 - val_accuracy: 0.9917
# Epoch 24/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0242 - accuracy: 0.9935 - val_loss: 0.0247 - val_accuracy: 0.9920
# Epoch 25/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0223 - accuracy: 0.9938 - val_loss: 0.0225 - val_accuracy: 0.9925
# Epoch 26/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0203 - accuracy: 0.9941 - val_loss: 0.0211 - val_accuracy: 0.9929
# Epoch 27/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.0193 - val_accuracy: 0.9934
# Epoch 28/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.0212 - val_accuracy: 0.9935
# Epoch 29/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.0175 - val_accuracy: 0.9938
# Epoch 30/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0172 - val_accuracy: 0.9940
# Epoch 31/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0149 - accuracy: 0.9954 - val_loss: 0.0166 - val_accuracy: 0.9942
# Epoch 32/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.0157 - val_accuracy: 0.9942
# Epoch 33/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0165 - accuracy: 0.9955 - val_loss: 0.0153 - val_accuracy: 0.9944
# Epoch 34/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0170 - accuracy: 0.9954 - val_loss: 0.0177 - val_accuracy: 0.9948
# Epoch 35/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.0176 - val_accuracy: 0.9950
# Epoch 36/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0149 - val_accuracy: 0.9952
# Epoch 37/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0123 - accuracy: 0.9963 - val_loss: 0.0162 - val_accuracy: 0.9955
# Epoch 38/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0155 - val_accuracy: 0.9957
# Epoch 39/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0158 - val_accuracy: 0.9958
# Epoch 40/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0146 - val_accuracy: 0.9959
# Epoch 41/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0152 - val_accuracy: 0.9960
# Epoch 42/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0158 - val_accuracy: 0.9961
# Epoch 43/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0151 - val_accuracy: 0.9962
# Epoch 44/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0150 - val_accuracy: 0.9963
# Epoch 45/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.0177 - val_accuracy: 0.9960
# Epoch 46/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0167 - val_accuracy: 0.9961
# Epoch 47/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.0149 - val_accuracy: 0.9963
# Epoch 48/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0097 - accuracy: 0.9971 - val_loss: 0.0148 - val_accuracy: 0.9964
# Epoch 49/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0165 - val_accuracy: 0.9962
# Epoch 50/50
# 192/192 [==============================] - 3s 18ms/sample - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.0162 - val_accuracy: 0.9963

# %% [markdown]
# ## Show history

# %%
history = model_container.history
plt.figure(figsize=(20, 10))
plt.subplot(211)
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.subplot(212)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

# %% [markdown]
# ## Prepare test images

# %%
color_mode = image_util.cv2_grayscale
if config.input_shape[2] == 3:
    color_mode = image_util.cv2_color
test_images = image_util.load_images(config.eval.files_path, color_mode)
tmp_imgs = []
for img in test_images:
    res = image_util.resize_image(img, config.input_shape[1], config.input_shape[0])
    norm = image_util.normalize(res, config.input_shape)
    tmp_imgs.append(norm)
test_images = np.array(tmp_imgs, dtype=np.float32)

# %% [markdown]
# ## Predict

# %%
model_container.predict(test_images)
model_container.plot_predictions(test_images)
